# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("./data/data.csv",index_col=0)

# %%
df.isnull().sum()
# Out:
# Id                      0
# class                   0
# num_sibling/spouse      0
# num_parent/child        0
# ticket                  0
# price                   0
# Seat                  668
# departure_from          2
# gender                  0
# alive                   0
# age                   174
# dtype: int64

# %%
#https://www.kaggle.com/code/gunesevitan/titanic-advanced-feature-engineering-tutorial?scriptVersionId=27280410&cellId=12
df_all_corr = df.corr().abs().unstack().sort_values(kind="quicksort", ascending=False).reset_index()
df_all_corr.rename(columns={"level_0": "Feature 1", "level_1": "Feature 2", 0: 'Correlation Coefficient'}, inplace=True)
df_all_corr[df_all_corr['Feature 1'] == 'age']
# Out:
#    Feature 1           Feature 2  Correlation Coefficient
# 6        age                 age                 1.000000
# 11       age               class                 0.370110
# 15       age  num_sibling/spouse                 0.312569
# 21       age    num_parent/child                 0.203935
# 25       age               price                 0.091529
# 31       age               alive                 0.077078
# 35       age                  Id                 0.043193

# %%
age_by_pclass_sex = df.groupby(['gender', 'class']).median()['age']

for pclass in range(1, 4):
    for gender in ['female', 'male']:
        print('Median age of Pclass {} {}s: {}'.format(pclass, gender, age_by_pclass_sex[gender][pclass]))
print('Median age of all passengers: {}'.format(df['age'].median()))

# Filling the missing values in age with the medians of Sex and Pclass groups
df['age'] = df.groupby(['gender', 'class'])['age'].apply(lambda x: x.fillna(x.median()))
# Out:
# Median age of Pclass 1 females: 35.0
# Median age of Pclass 1 males: 42.0
# Median age of Pclass 2 females: 29.0
# Median age of Pclass 2 males: 30.0
# Median age of Pclass 3 females: 21.0
# Median age of Pclass 3 males: 25.0
# Median age of all passengers: 28.0

# %%
df[df["departure_from"].isnull()]
# Out:
#       Id  class  num_sibling/spouse  num_parent/child      ticket  price Seat  \
# 61    62      1                   0                 0  Y7YW04RMB3   80.0  B28
# 829  830      1                   0                 0  Y7YW04RMB3   80.0  B28
#
#     departure_from  gender  alive   age
# 61             NaN  female      1  38.0
# 829            NaN  female      1  62.0

# %% [markdown]
# https://www.encyclopedia-titanica.org/titanic-survivor/martha-evelyn-stone.html
# These 2 people are them

# %%
df["departure_from"]=df["departure_from"].fillna("S")

# %%
df[~df["Seat"].isnull()]
# Out:
#       Id  class  num_sibling/spouse  num_parent/child      ticket    price  \
# 1      2      1                   1                 0  RWKPI7Y5RI  71.2833
# 3      4      1                   1                 0  B46YX3C4TM  53.1000
# 6      7      1                   0                 0  D0H80AU5I9  51.8625
# 10    11      3                   1                 1  HJZUAK0BM5  16.7000
# 11    12      1                   0                 0  5T631824EH  26.5500
# ..   ...    ...                 ...               ...         ...      ...
# 839  840      1                   0                 0  N65N3LIJCA  29.7000
# 849  850      1                   1                 0  IZLXRECH1T  89.1042
# 853  854      1                   0                 1  T9D19PG2JT  39.4000
# 857  858      1                   0                 0  18HYSKBAC5  26.5500
# 862  863      1                   0                 0  DGHP5IG5FR  25.9292
#
#      Seat departure_from  gender  alive   age
# 1     C85              C  female      1  38.0
# 3    C123              S  female      1  35.0
# 6     E46              S    male      0  54.0
# 10     G6              S  female      1   4.0
# 11   C103              S  female      1  58.0
# ..    ...            ...     ...    ...   ...
# 839   C47              C    male      1  42.0
# 849   C92              C  female      1  35.0
# 853   D28              S  female      1  16.0
# 857   E17              S    male      1  51.0
# 862   D17              S  female      1  48.0
#
# [198 rows x 11 columns]

# %%
df[~df["Seat"].isnull()]["Seat"].unique()
# Out:
# array(['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'C23 C25 C27',
#        'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'F G73', 'E31',
#        'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101', 'F E69', 'D47',
#        'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4',
#        'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77',
#        'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'D',
#        'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66', 'C7',
#        'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128', 'D37',
#        'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
#        'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63', 'C62 C64',
#        'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30', 'E121',
#        'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36', 'B102',
#        'B69', 'E49', 'C47', 'D28', 'E17'], dtype=object)

# %% [markdown]
# https://triangleinequality.wordpress.com/2013/09/08/basic-feature-engineering-with-the-titanic-data/

# %%
df['Family_Size']=df['num_sibling/spouse']+df['num_parent/child']

# %%
import re

# %%
#Turning Seat into Deck

df['Seat']=df["Seat"].where(pd.notnull(df["Seat"]), 'Unknown')
df['Deck']=df['Seat'].map(lambda x: re.search("\\b\\d+",x)[0] if re.search("\\b\\d+",x) else x)

# %% [markdown]
# We can split the deck into position and the level of cabin

# %%
df['position']=df['Deck'].map(lambda x: re.search("\\d+",x)[0] if re.search("\\d+",x) else "Unknown")

# %%
df['position'].unique()
# Out:
# array(['Unknown', '85', '123', '46', '6', '103', '56', '23', '78', '33',
#        '30', '52', '28', '83', '73', '31', '5', '10', '26', '110', '58',
#        '101', '69', '47', '86', '2', '19', '7', '49', '4', '32', '80',
#        '36', '15', '93', '35', '87', '77', '67', '94', '125', '99', '118',
#        '22', '106', '65', '54', '57', '34', '18', '124', '91', '40',
#        '128', '37', '50', '82', '96', '44', '104', '111', '92', '38',
#        '21', '12', '63', '14', '20', '79', '25', '95', '39', '70', '16',
#        '68', '41', '9', '48', '126', '71', '51', '62', '24', '90', '45',
#        '8', '121', '11', '3', '17', '102'], dtype=object)

# %%
df['level']=df['Deck'].map(lambda x: re.search("[A-Z]{1,}",x)[0])

# %%
df['level'].unique()
# Out:
# array(['U', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %% [markdown]
# U is unknown

# %%
df.isnull().sum()
# Out:
# Id                    0
# class                 0
# num_sibling/spouse    0
# num_parent/child      0
# ticket                0
# price                 0
# Seat                  0
# departure_from        0
# gender                0
# alive                 0
# age                   0
# Family_Size           0
# Deck                  0
# position              0
# level                 0
# dtype: int64

# %%
df1=df.drop(["Seat",'Deck'],axis=1)

# %%
df1
# Out:
#       Id  class  num_sibling/spouse  num_parent/child      ticket    price  \
# 0      1      3                   1                 0  CUGSP1ULC1   7.2500
# 1      2      1                   1                 0  RWKPI7Y5RI  71.2833
# 2      3      3                   0                 0  DTHA121ED6   7.9250
# 3      4      1                   1                 0  B46YX3C4TM  53.1000
# 4      5      3                   0                 0  YJKMT1KA7C   8.0500
# ..   ...    ...                 ...               ...         ...      ...
# 861  862      2                   1                 0  653K8328Q7  11.5000
# 862  863      1                   0                 0  DGHP5IG5FR  25.9292
# 863  864      3                   8                 2  8CLGUH86EQ  69.5500
# 864  865      2                   0                 0  0B9361U0EC  13.0000
# 865  866      2                   0                 0  35ZWW11YZO  13.0000
#
#     departure_from  gender  alive   age  Family_Size position level
# 0                S    male      0  22.0            1  Unknown     U
# 1                C  female      1  38.0            1       85     C
# 2                S  female      1  26.0            0  Unknown     U
# 3                S  female      1  35.0            1      123     C
# 4                S    male      0  35.0            0  Unknown     U
# ..             ...     ...    ...   ...          ...      ...   ...
# 861              S    male      0  21.0            1  Unknown     U
# 862              S  female      1  48.0            0       17     D
# 863              S  female      0  21.0           10  Unknown     U
# 864              S    male      0  24.0            0  Unknown     U
# 865              S  female      1  42.0            0  Unknown     U
#
# [866 rows x 13 columns]

# %%
df2=df1.merge(df1.groupby("ticket")["price"].mean(),on="ticket",how="outer")

# %%
df2[df2["price_x"]!=df2["price_y"]]
# Out:
#       Id  class  num_sibling/spouse  num_parent/child      ticket   price_x  \
# 110   64      3                   3                 2  QSFWFFSU89   27.9000
# 111  168      3                   1                 4  QSFWFFSU89   27.9000
# 112  361      3                   1                 4  QSFWFFSU89   27.9000
# 113  635      3                   3                 2  QSFWFFSU89   27.9000
# 114  643      3                   3                 2  QSFWFFSU89   27.9000
# 115  820      3                   3                 2  QSFWFFSU89   27.9000
# 130   75      3                   0                 0  Q2E163PJZE   56.4958
# 131  170      3                   0                 0  Q2E163PJZE   56.4958
# 132  510      3                   0                 0  Q2E163PJZE   56.4958
# 133  644      3                   0                 0  Q2E163PJZE   56.4958
# 134  693      3                   0                 0  Q2E163PJZE   56.4958
# 135  827      3                   0                 0  Q2E163PJZE   56.4958
# 136  839      3                   0                 0  Q2E163PJZE   56.4958
# 180  110      3                   1                 0  D7GR7MJG2G   24.1500
# 181  518      3                   0                 0  D7GR7MJG2G   24.1500
# 182  769      3                   1                 0  D7GR7MJG2G   24.1500
# 301  216      1                   1                 0  3SSYHVCFTC  113.2750
# 302  394      1                   1                 0  3SSYHVCFTC  113.2750
# 303  660      1                   0                 2  3SSYHVCFTC  113.2750
# 525  420      3                   0                 2  FQDWU0KKOC   24.1500
# 526  596      3                   1                 1  FQDWU0KKOC   24.1500
# 527  800      3                   1                 1  FQDWU0KKOC   24.1500
#
#     departure_from  gender  alive   age  Family_Size position level   price_y
# 110              S    male      0   4.0            5  Unknown     U   27.9000
# 111              S  female      0  45.0            5  Unknown     U   27.9000
# 112              S    male      0  40.0            5  Unknown     U   27.9000
# 113              S  female      0   9.0            5  Unknown     U   27.9000
# 114              S  female      0   2.0            5  Unknown     U   27.9000
# 115              S    male      0  10.0            5  Unknown     U   27.9000
# 130              S    male      1  32.0            0  Unknown     U   56.4958
# 131              S    male      0  28.0            0  Unknown     U   56.4958
# 132              S    male      1  26.0            0  Unknown     U   56.4958
# 133              S    male      1  25.0            0  Unknown     U   56.4958
# 134              S    male      1  25.0            0  Unknown     U   56.4958
# 135              S    male      0  25.0            0  Unknown     U   56.4958
# 136              S    male      1  32.0            0  Unknown     U   56.4958
# 180              Q  female      1  21.0            1  Unknown     U   24.1500
# 181              Q    male      0  25.0            0  Unknown     U   24.1500
# 182              Q    male      0  25.0            1  Unknown     U   24.1500
# 301              C  female      1  31.0            1       36     D  113.2750
# 302              C  female      1  23.0            1       36     D  113.2750
# 303              C    male      0  58.0            2       48     D  113.2750
# 525              S  female      0  10.0            2  Unknown     U   24.1500
# 526              S    male      0  36.0            2  Unknown     U   24.1500
# 527              S  female      0  30.0            2  Unknown     U   24.1500

# %% [markdown]
# Price is already fare per person, we do not need to divide the fare by family members

# %%
df1.groupby("alive")["age"].plot.hist(legend=True,alpha=0.5,bins=20)
# Out:
# alive
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: age, dtype: object

# %% [markdown]
# It seems children(age<15) have a high % of survival, we should explicitly create a feature for this

# %%
child =15

# %%
df1["minor"]=df1["age"]<15

# %%
sum(df1["minor"])
# Out:
# 77

# %% [markdown]
# There are 77 minors

# %%
df1
# Out:
#       Id  class  num_sibling/spouse  num_parent/child      ticket    price  \
# 0      1      3                   1                 0  CUGSP1ULC1   7.2500
# 1      2      1                   1                 0  RWKPI7Y5RI  71.2833
# 2      3      3                   0                 0  DTHA121ED6   7.9250
# 3      4      1                   1                 0  B46YX3C4TM  53.1000
# 4      5      3                   0                 0  YJKMT1KA7C   8.0500
# ..   ...    ...                 ...               ...         ...      ...
# 861  862      2                   1                 0  653K8328Q7  11.5000
# 862  863      1                   0                 0  DGHP5IG5FR  25.9292
# 863  864      3                   8                 2  8CLGUH86EQ  69.5500
# 864  865      2                   0                 0  0B9361U0EC  13.0000
# 865  866      2                   0                 0  35ZWW11YZO  13.0000
#
#     departure_from  gender  alive   age  Family_Size position level  minor
# 0                S    male      0  22.0            1  Unknown     U  False
# 1                C  female      1  38.0            1       85     C  False
# 2                S  female      1  26.0            0  Unknown     U  False
# 3                S  female      1  35.0            1      123     C  False
# 4                S    male      0  35.0            0  Unknown     U  False
# ..             ...     ...    ...   ...          ...      ...   ...    ...
# 861              S    male      0  21.0            1  Unknown     U  False
# 862              S  female      1  48.0            0       17     D  False
# 863              S  female      0  21.0           10  Unknown     U  False
# 864              S    male      0  24.0            0  Unknown     U  False
# 865              S  female      1  42.0            0  Unknown     U  False
#
# [866 rows x 14 columns]

# %%
df1["level"]=df1["level"].replace({"U":None})

# %%
df1["position"]=df1["position"].replace({"Unknown":None})

# %%
df1.to_csv("cleaned_data.csv")
